# %%
print("ok")
# Out:
# ok

# %% [markdown]
# # Configbox

# %%
import yaml

# Specify the path to your YAML file
yaml_file_path = 'test.yaml'

# Open the YAML file and load its contents
with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)

# Now you can work with the data loaded from the YAML file
print(data)
print(type(data))
# Out:
# {'name': 'Kamlesh', 'Email': 'kamleshpadwal@gmail.com'}
# <class 'dict'>

# %%
data['name']
# Out:
# 'Kamlesh'

# %%
data['Email']
# Out:
# 'kamleshpadwal@gmail.com'

# %%
data.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.name
#
# AttributeError: 'dict' object has no attribute 'name'

# %%
from box import ConfigBox

# %%
data
# Out:
# {'name': 'Kamlesh', 'Email': 'kamleshpadwal@gmail.com'}

# %%
obj = ConfigBox(data)
obj
# Out:
# ConfigBox({'name': 'Kamlesh', 'Email': 'kamleshpadwal@gmail.com'})

# %%
obj.name
# Out:
# 'Kamlesh'

# %%
obj.Email
# Out:
# 'kamleshpadwal@gmail.com'

# %% [markdown]
# # ensure_annotations

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 4)

# %%
get_product(x = 2, y = "4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 4)
# Out:
# 8

# %%
get_product(x = 2, y = "4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_product(x = 2, y = "4")
#
# File c:\Users\C\anaconda3\envs\chest\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x00000238EB3A49D0> does not match annotation type <class 'int'>

# %% [markdown]
# # Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1z0mreUtRmR-P-magILsDR3T7M6IkGXtY/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
url.split("/")
# Out:
# ['https:',
#  '',
#  'drive.google.com',
#  'file',
#  'd',
#  '1z0mreUtRmR-P-magILsDR3T7M6IkGXtY',
#  'view?usp=sharing']

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1z0mreUtRmR-P-magILsDR3T7M6IkGXtY'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.usercontent.google.com/download?id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=430a96cc-275e-4582-bd80-afba367cd509
# To: f:\Data Science  Projects\Chest-Disease-Classification-from-Chest-CT-Scan-Image\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:06<00:00, 7.52MB/s]
# 'Chest-CT-Scan-data.zip'
